# %%
conda init
# Out:
# no change     /Users/aesthetic/opt/anaconda3/condabin/conda
# no change     /Users/aesthetic/opt/anaconda3/bin/conda
# no change     /Users/aesthetic/opt/anaconda3/bin/conda-env
# no change     /Users/aesthetic/opt/anaconda3/bin/activate
# no change     /Users/aesthetic/opt/anaconda3/bin/deactivate
# no change     /Users/aesthetic/opt/anaconda3/etc/profile.d/conda.sh
# no change     /Users/aesthetic/opt/anaconda3/etc/fish/conf.d/conda.fish
# no change     /Users/aesthetic/opt/anaconda3/shell/condabin/Conda.psm1
# no change     /Users/aesthetic/opt/anaconda3/shell/condabin/conda-hook.ps1
# no change     /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages/xontrib/conda.xsh
# no change     /Users/aesthetic/opt/anaconda3/etc/profile.d/conda.csh
# no change     /Users/aesthetic/.bash_profile
# No action taken.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install alpha_vantage pandas
# Out:
# Requirement already satisfied: alpha_vantage in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (2.3.1)
# Requirement already satisfied: pandas in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (1.1.3)
# Requirement already satisfied: aiohttp in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from alpha_vantage) (3.7.3)
# Requirement already satisfied: requests in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from alpha_vantage) (2.24.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (20.3.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (3.0.4)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests->alpha_vantage) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests->alpha_vantage) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests->alpha_vantage) (2020.6.20)
# Requirement already satisfied: six>=1.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
from alpha_vantage.techindicators import TechIndicators
from datetime import date
from datetime import timedelta

import matplotlib.pyplot as plt 
import sys
import pandas as pd
import time

# %%
# Obtaining stock data from alpha vantage 
sym='AAPL'

#obtains stock data from the previous day date to 2018-11-29
def stock_data(symbol):
    ts = TimeSeries(key='SUXOFAIGXM6HEP9Y', output_format='pandas')
    data, meta_data = ts.get_daily_adjusted(symbol=sym, outputsize='full')
    data_date_changed = data[:'2018-11-29']
    return data_date_changed

data_dated = stock_data(sym)

# %%
time.sleep(20)

# %%
# *****************************Technical Indicators*******************************************************************

# %%
# *****************************SMA*******************************************************************

# getting the date of the previous day
yday= date.today()- timedelta(1) 

# technical indicators from alphavantage
ti = TechIndicators(key = 'SUXOFAIGXM6HEP9Y', output_format = 'pandas')

# obtaining sma inidcator from alpha vantage
stockSMA, meta_data= ti.get_sma(symbol = sym, interval = 'daily',time_period = 20)

# resting index so that date is no longer the index
stockSMA.reset_index(inplace = True) 

# sorting date column in decending order
stockSMA.sort_values(by=['date'], inplace=True, ascending=False)

# filtering date 
mask = (stockSMA['date'] > '2018-11-29') & (stockSMA['date'] <=pd.to_datetime(yday))

stockSMA = stockSMA.loc[mask]


stockSMA.head(20)

# resetting index 
stockSMA.set_index('date', inplace=True)


data_dated['SMA']= stockSMA[['SMA']].copy()

# %%
# *****************************EMA*******************************************************************


# obtaining EMA inidcator from alpha vantage
stockEMA,q= ti.get_ema(symbol = sym, interval = 'daily', time_period = 20)

# resting index so that date is no longer the index
stockEMA.reset_index(inplace = True) 

# sorting date column in decending order
stockEMA.sort_values(by=['date'], inplace=True, ascending=False)

# filtering date 
mask = (stockEMA['date'] > '2018-11-29') & (stockEMA['date'] <=pd.to_datetime(yday))

stockEMA = stockEMA.loc[mask]


stockEMA.head(20)

# resetting index 
stockEMA.set_index('date', inplace=True)


data_dated['EMA']= stockEMA[['EMA']].copy()

# %%
time.sleep(20)

# %%
data_dated.head(20)
# Out:
#             1. open   2. high    3. low  4. close  5. adjusted close  \
# date
# 2021-01-22   136.28  139.8500  135.0200    139.07             139.07
# 2021-01-21   133.80  139.6700  133.5900    136.87             136.87
# 2021-01-20   128.66  132.4900  128.5500    132.03             132.03
# 2021-01-19   127.78  128.7100  126.9380    127.83             127.83
# 2021-01-15   128.78  130.2242  127.0000    127.14             127.14
# 2021-01-14   130.80  131.0000  128.7600    128.91             128.91
# 2021-01-13   128.76  131.4500  128.4900    130.89             130.89
# 2021-01-12   128.50  129.6900  126.8600    128.80             128.80
# 2021-01-11   129.19  130.1700  128.5000    128.98             128.98
# 2021-01-08   132.43  132.6300  130.2300    132.05             132.05
# 2021-01-07   128.36  131.6300  127.8600    130.92             130.92
# 2021-01-06   127.72  131.0499  126.3820    126.60             126.60
# 2021-01-05   128.89  131.7400  128.4300    131.01             131.01
# 2021-01-04   133.52  133.6116  126.7600    129.41             129.41
# 2020-12-31   134.08  134.7400  131.7200    132.69             132.69
# 2020-12-30   135.58  135.9900  133.4000    133.72             133.72
# 2020-12-29   138.05  138.7890  134.3409    134.87             134.87
# 2020-12-28   133.99  137.3400  133.5100    136.69             136.69
# 2020-12-24   131.32  133.4600  131.1000    131.97             131.97
# 2020-12-23   132.16  132.4300  130.7800    130.96             130.96
#
#               6. volume  7. dividend amount  8. split coefficient       SMA  \
# date
# 2021-01-22  108764173.0                 0.0                   1.0       NaN
# 2021-01-21  120529544.0                 0.0                   1.0  131.2110
# 2021-01-20  104319489.0                 0.0                   1.0  130.7790
# 2021-01-19   90757329.0                 0.0                   1.0  130.5102
# 2021-01-15  111598531.0                 0.0                   1.0  130.5537
# 2021-01-14   90221755.0                 0.0                   1.0  130.5872
# 2021-01-13   88636831.0                 0.0                   1.0  130.5357
# 2021-01-12   90440255.0                 0.0                   1.0  130.0803
# 2021-01-11  100620880.0                 0.0                   1.0  129.7607
# 2021-01-08  105158245.0                 0.0                   1.0  129.4737
# 2021-01-07  109578157.0                 0.0                   1.0  128.9602
# 2021-01-06  155087970.0                 0.0                   1.0  128.6332
# 2021-01-05   97664898.0                 0.0                   1.0  128.4907
# 2021-01-04  143301887.0                 0.0                   1.0  128.0527
# 2020-12-31   99116586.0                 0.0                   1.0  127.7292
# 2020-12-30   96452124.0                 0.0                   1.0  127.2487
# 2020-12-29  121047324.0                 0.0                   1.0  126.6987
# 2020-12-28  123124632.0                 0.0                   1.0  125.9077
# 2020-12-24   54930064.0                 0.0                   1.0  124.9027
# 2020-12-23   88223692.0                 0.0                   1.0  124.1058
#
#                  EMA
# date
# 2021-01-22       NaN
# 2021-01-21  129.9283
# 2021-01-20  129.1976
# 2021-01-19  128.8995
# 2021-01-15  129.0121
# 2021-01-14  129.2091
# 2021-01-13  129.2406
# 2021-01-12  129.0670
# 2021-01-11  129.0951
# 2021-01-08  129.1072
# 2021-01-07  128.7975
# 2021-01-06  128.5740
# 2021-01-05  128.7818
# 2021-01-04  128.5473
# 2020-12-31  128.4565
# 2020-12-30  128.0108
# 2020-12-29  127.4099
# 2020-12-28  126.6246
# 2020-12-24  125.5651
# 2020-12-23  124.8909

# %%
# *****************************MACD*******************************************************************

# obtaining MACD inidcator from alpha vantage
stockMACD,q= ti.get_macd(symbol = sym, interval = 'daily', fastperiod = 12, slowperiod = 26, signalperiod = 9)

# resting index so that date is no longer the index
stockMACD.reset_index(inplace = True) 

# sorting date column in decending order
stockMACD.sort_values(by=['date'], inplace=True, ascending=False)


# filtering date 
mask = (stockMACD['date'] > '2018-11-29') & (stockMACD['date'] <=pd.to_datetime(yday))

stockMACD = stockMACD.loc[mask]


stockMACD.head(20)

# resetting index 
stockMACD.set_index('date', inplace=True)


data_dated['MACD']= stockMACD[['MACD']].copy()

# %%
# ***********************************Bollinger Bands*******************************************************************
stockbbands, q = ti.get_bbands(symbol = sym, interval = 'daily', time_period = 20, nbdevup = 2, nbdevdn = 2, matype = 0)

# resting index so that date is no longer the index
stockbbands.reset_index(inplace = True) 

# sorting date column in decending order
stockbbands.sort_values(by=['date'], inplace=True, ascending=False)

# filtering date 
mask = (stockbbands['date'] > '2018-11-29') & (stockbbands['date'] <=pd.to_datetime(yday))

stockbbands = stockbbands.loc[mask]


stockbbands.head(20)

# resetting index 
stockbbands.set_index('date', inplace=True)


data_dated['Real Lower Band']= stockbbands[['Real Lower Band']].copy()
data_dated['Real Upper Band']= stockbbands[['Real Upper Band']].copy()
data_dated['Real Middle Band']= stockbbands[['Real Middle Band']].copy()

# %%
time.sleep(20)

# %%
# ***********************************Stochastic oscillator*******************************************************************
stockStoch, meta_data = ti.get_stoch(symbol=sym, interval='daily')

# resting index so that date is no longer the index
stockStoch.reset_index(inplace = True) 

# sorting date column in decending order
stockStoch.sort_values(by=['date'], inplace=True, ascending=False)


# filtering date 
mask = (stockStoch['date'] > '2018-11-29') & (stockStoch['date'] <=pd.to_datetime(yday))

stockStoch = stockStoch.loc[mask]


stockStoch.head(20)

# resetting index 
stockStoch.set_index('date', inplace=True)


data_dated['SlowK']= stockStoch[['SlowK']].copy()
data_dated['SlowD']= stockStoch[['SlowD']].copy()

# %%
time.sleep(20)

# %%
# ***********************************Accumulation/Distribution Line(A/D)*******************************************************************
stockAD, meta_data = ti.get_stoch(symbol=sym, interval='daily')


# resting index so that date is no longer the index
stockAD.reset_index(inplace = True) 

# sorting date column in decending order
stockAD.sort_values(by=['date'], inplace=True, ascending=False)

# filtering date 
mask = (stockAD['date'] > '2018-11-29') & (stockAD['date'] <=pd.to_datetime(yday))

stockAD = stockAD.loc[mask]


stockAD.head(20)

# resetting index 
# stockAD.set_index('date', inplace=True)


# data_dated['SlowK']= stockAD[['SlowK']].copy()
# data_dated['SlowD']= stockAD[['SlowD']].copy()
# Out:
#          date    SlowK    SlowD
# 1  2021-01-21  63.6186  41.3961
# 2  2021-01-20  39.6493  32.5758
# 3  2021-01-19  20.9206  35.3675
# 4  2021-01-15  37.1576  45.0746
# 5  2021-01-14  48.0243  50.3200
# 6  2021-01-13  50.0419  53.6760
# 7  2021-01-12  52.8939  51.9914
# 8  2021-01-11  58.0922  44.5707
# 9  2021-01-08  44.9880  31.8322
# 10 2021-01-07  30.6318  25.5073
# 11 2021-01-06  19.8768  24.1209
# 12 2021-01-05  26.0134  30.2182
# 13 2021-01-04  26.4726  42.5634
# 14 2020-12-31  38.1685  59.3184
# 15 2020-12-30  63.0491  73.4458
# 16 2020-12-29  76.7378  77.2388
# 17 2020-12-28  80.5505  76.4917
# 18 2020-12-24  74.4280  73.9253
# 19 2020-12-23  74.4967  74.8776
# 20 2020-12-22  72.8511  77.4966

# %%
# ***********************************On Balance Volume (obv)*******************************************************************


# obtaining OBV inidcator from alpha vantage
stockOBV,q= ti.get_obv(symbol = 'TSLA', interval = 'daily')

# resting index so that date is no longer the index
stockOBV.reset_index(inplace = True) 

# sorting date column in decending order
stockOBV.sort_values(by=['date'], inplace=True, ascending=False)

# filtering date 
mask = (stockOBV['date'] > '2018-11-29') & (stockOBV['date'] <=pd.to_datetime(yday))

stockOBV = stockOBV.loc[mask]


stockOBV.head(20)

# resetting index 
stockOBV.set_index('date', inplace=True)


data_dated['OBV']= stockOBV[['OBV']].copy()

# %%
data_dated.head(20)
# Out:
#             1. open   2. high    3. low  4. close  5. adjusted close  \
# date
# 2021-01-22   136.28  139.8500  135.0200    139.07             139.07
# 2021-01-21   133.80  139.6700  133.5900    136.87             136.87
# 2021-01-20   128.66  132.4900  128.5500    132.03             132.03
# 2021-01-19   127.78  128.7100  126.9380    127.83             127.83
# 2021-01-15   128.78  130.2242  127.0000    127.14             127.14
# 2021-01-14   130.80  131.0000  128.7600    128.91             128.91
# 2021-01-13   128.76  131.4500  128.4900    130.89             130.89
# 2021-01-12   128.50  129.6900  126.8600    128.80             128.80
# 2021-01-11   129.19  130.1700  128.5000    128.98             128.98
# 2021-01-08   132.43  132.6300  130.2300    132.05             132.05
# 2021-01-07   128.36  131.6300  127.8600    130.92             130.92
# 2021-01-06   127.72  131.0499  126.3820    126.60             126.60
# 2021-01-05   128.89  131.7400  128.4300    131.01             131.01
# 2021-01-04   133.52  133.6116  126.7600    129.41             129.41
# 2020-12-31   134.08  134.7400  131.7200    132.69             132.69
# 2020-12-30   135.58  135.9900  133.4000    133.72             133.72
# 2020-12-29   138.05  138.7890  134.3409    134.87             134.87
# 2020-12-28   133.99  137.3400  133.5100    136.69             136.69
# 2020-12-24   131.32  133.4600  131.1000    131.97             131.97
# 2020-12-23   132.16  132.4300  130.7800    130.96             130.96
#
#               6. volume  7. dividend amount  8. split coefficient       SMA  \
# date
# 2021-01-22  108764173.0                 0.0                   1.0       NaN
# 2021-01-21  120529544.0                 0.0                   1.0  131.2110
# 2021-01-20  104319489.0                 0.0                   1.0  130.7790
# 2021-01-19   90757329.0                 0.0                   1.0  130.5102
# 2021-01-15  111598531.0                 0.0                   1.0  130.5537
# 2021-01-14   90221755.0                 0.0                   1.0  130.5872
# 2021-01-13   88636831.0                 0.0                   1.0  130.5357
# 2021-01-12   90440255.0                 0.0                   1.0  130.0803
# 2021-01-11  100620880.0                 0.0                   1.0  129.7607
# 2021-01-08  105158245.0                 0.0                   1.0  129.4737
# 2021-01-07  109578157.0                 0.0                   1.0  128.9602
# 2021-01-06  155087970.0                 0.0                   1.0  128.6332
# 2021-01-05   97664898.0                 0.0                   1.0  128.4907
# 2021-01-04  143301887.0                 0.0                   1.0  128.0527
# 2020-12-31   99116586.0                 0.0                   1.0  127.7292
# 2020-12-30   96452124.0                 0.0                   1.0  127.2487
# 2020-12-29  121047324.0                 0.0                   1.0  126.6987
# 2020-12-28  123124632.0                 0.0                   1.0  125.9077
# 2020-12-24   54930064.0                 0.0                   1.0  124.9027
# 2020-12-23   88223692.0                 0.0                   1.0  124.1058
#
#                  EMA    MACD  Real Lower Band  Real Upper Band  \
# date
# 2021-01-22       NaN     NaN              NaN              NaN
# 2021-01-21  129.9283  1.6579         125.6397         136.7823
# 2021-01-20  129.1976  1.1726         125.7129         135.8451
# 2021-01-19  128.8995  1.0289         125.1750         135.8455
# 2021-01-15  129.0121  1.2582         125.2929         135.8146
# 2021-01-14  129.2091  1.6028         125.4059         135.7686
# 2021-01-13  129.2406  1.8392         125.2690         135.8025
# 2021-01-12  129.0670  1.9125         123.5828         136.5777
# 2021-01-11  129.0951  2.1910         122.4637         137.0578
# 2021-01-08  129.1072  2.4963         121.6443         137.3032
# 2021-01-07  128.7975  2.5371         120.5486         137.3719
# 2021-01-06  128.5740  2.6673         120.0451         137.2214
# 2021-01-05  128.7818  3.2345         119.6807         137.3008
# 2021-01-04  128.5473  3.4624         118.9220         137.1835
# 2020-12-31  128.4565  3.8659         118.3585         137.1000
# 2020-12-30  128.0108  3.9907         117.9596         136.5379
# 2020-12-29  127.4099  3.9871         117.7096         135.6879
# 2020-12-28  126.6246  3.8073         117.1528         134.6627
# 2020-12-24  125.5651  3.3373         116.7344         133.0711
# 2020-12-23  124.8909  3.1693         115.7429         132.4686
#
#             Real Middle Band    SlowK    SlowD           OBV
# date
# 2021-01-22               NaN      NaN      NaN           NaN
# 2021-01-21          131.2110  63.6186  41.3961  5.405505e+09
# 2021-01-20          130.7790  39.6493  32.5758  5.426103e+09
# 2021-01-19          130.5102  20.9206  35.3675  5.400437e+09
# 2021-01-15          130.5537  37.1576  45.0746  5.375070e+09
# 2021-01-14          130.5872  48.0243  50.3200  5.413848e+09
# 2021-01-13          130.5357  50.0419  53.6760  5.445114e+09
# 2021-01-12          130.0803  52.8939  51.9914  5.411801e+09
# 2021-01-11          129.7607  58.0922  44.5707  5.365816e+09
# 2021-01-08          129.4737  44.9880  31.8322  5.425370e+09
# 2021-01-07          128.9602  30.6318  25.5073  5.350315e+09
# 2021-01-06          128.6332  19.8768  24.1209  5.298816e+09
# 2021-01-05          128.4907  26.0134  30.2182  5.254116e+09
# 2021-01-04          128.0527  26.4726  42.5634  5.221870e+09
# 2020-12-31          127.7292  38.1685  59.3184  5.173232e+09
# 2020-12-30          127.2487  63.0491  73.4458  5.123582e+09
# 2020-12-29          126.6987  76.7378  77.2388  5.080736e+09
# 2020-12-28          125.9077  80.5505  76.4917  5.057825e+09
# 2020-12-24          124.9027  74.4280  73.9253  5.026272e+09
# 2020-12-23          124.1058  74.4967  74.8776  5.003406e+09

# %%
time.sleep(20)
