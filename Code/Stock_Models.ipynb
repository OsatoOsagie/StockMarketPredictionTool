# %% [markdown]
# Import Libraries and Dataset

# %% [markdown]
# Alpha Vantage Description here !!!!!!!!!!!!!!!!

# %%
pip install alpha_vantage pandas
# Out:
# Requirement already satisfied: alpha_vantage in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (2.3.1)
# Requirement already satisfied: pandas in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (1.1.3)
# Requirement already satisfied: aiohttp in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from alpha_vantage) (3.7.3)
# Requirement already satisfied: requests in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from alpha_vantage) (2.24.0)
# Requirement already satisfied: numpy>=1.15.4 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (3.7.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (20.3.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (3.0.4)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->alpha_vantage) (1.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests->alpha_vantage) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests->alpha_vantage) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests->alpha_vantage) (2.10)
# Requirement already satisfied: six>=1.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Plotly Description

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Tensoflow description

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: wheel~=0.35 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: google-pasta~=0.2 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy~=1.19.2 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorboard~=2.4 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: absl-py~=0.10 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: gast==0.3.3 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio~=1.32.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: six~=1.15.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: h5py~=2.10.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.27.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (0.4.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (3.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/aesthetic/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
from alpha_vantage.techindicators import TechIndicators
from datetime import date
from datetime import timedelta

import pandas as pd
import plotly.express as px
from copy import copy
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import plotly.figure_factory as ff
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from tensorflow import keras

# %%
# Obtaining stock data from alpha vantage 
stock='VOO'


def stock_data(stock):
    ts = TimeSeries(key='SUXOFAIGXM6HEP9Y', output_format='pandas')
    data, meta_data = ts.get_daily_adjusted(symbol=stock, outputsize='full')
    data_date_changed = data[:'2019-01-01']
    data_date_changed['Ticker']= stock
    return data_date_changed

# %%
raw_data= stock_data(stock)

# %%
raw_data.tail(10)
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2019-01-15   236.97   239.59  236.97    239.35         230.370959  5103721.0
# 2019-01-14   236.10   237.39  235.69    236.58         227.704873  2653373.0
# 2019-01-11   236.85   238.00  236.24    237.89         228.965729  2551033.0
# 2019-01-10   235.65   238.17  234.85    238.00         229.071603  2813503.0
# 2019-01-09   236.71   237.94  235.46    237.01         228.118742  4564975.0
# 2019-01-08   236.05   236.46  233.43    235.92         227.069633  3546649.0
# 2019-01-07   232.29   235.23  231.32    233.65         224.884790  3706014.0
# 2019-01-04   227.54   232.62  227.15    231.91         223.210065  5100088.0
# 2019-01-03   228.10   228.42  223.97    224.50         216.078046  3330026.0
# 2019-01-02   226.18   230.85  226.02    229.99         221.362092  4891329.0
#
#             7. dividend amount  8. split coefficient Ticker
# date
# 2019-01-15                 0.0                   1.0    VOO
# 2019-01-14                 0.0                   1.0    VOO
# 2019-01-11                 0.0                   1.0    VOO
# 2019-01-10                 0.0                   1.0    VOO
# 2019-01-09                 0.0                   1.0    VOO
# 2019-01-08                 0.0                   1.0    VOO
# 2019-01-07                 0.0                   1.0    VOO
# 2019-01-04                 0.0                   1.0    VOO
# 2019-01-03                 0.0                   1.0    VOO
# 2019-01-02                 0.0                   1.0    VOO

# %%
 
raw_data['Date']= raw_data.index

# %%
raw_data= raw_data.sort_values(by=['date'])

# %%
raw_data.head(10)
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2019-01-02   226.18   230.85  226.02    229.99         221.362092  4891329.0
# 2019-01-03   228.10   228.42  223.97    224.50         216.078046  3330026.0
# 2019-01-04   227.54   232.62  227.15    231.91         223.210065  5100088.0
# 2019-01-07   232.29   235.23  231.32    233.65         224.884790  3706014.0
# 2019-01-08   236.05   236.46  233.43    235.92         227.069633  3546649.0
# 2019-01-09   236.71   237.94  235.46    237.01         228.118742  4564975.0
# 2019-01-10   235.65   238.17  234.85    238.00         229.071603  2813503.0
# 2019-01-11   236.85   238.00  236.24    237.89         228.965729  2551033.0
# 2019-01-14   236.10   237.39  235.69    236.58         227.704873  2653373.0
# 2019-01-15   236.97   239.59  236.97    239.35         230.370959  5103721.0
#
#             7. dividend amount  8. split coefficient Ticker       Date
# date
# 2019-01-02                 0.0                   1.0    VOO 2019-01-02
# 2019-01-03                 0.0                   1.0    VOO 2019-01-03
# 2019-01-04                 0.0                   1.0    VOO 2019-01-04
# 2019-01-07                 0.0                   1.0    VOO 2019-01-07
# 2019-01-08                 0.0                   1.0    VOO 2019-01-08
# 2019-01-09                 0.0                   1.0    VOO 2019-01-09
# 2019-01-10                 0.0                   1.0    VOO 2019-01-10
# 2019-01-11                 0.0                   1.0    VOO 2019-01-11
# 2019-01-14                 0.0                   1.0    VOO 2019-01-14
# 2019-01-15                 0.0                   1.0    VOO 2019-01-15

# %%
 #check if any null values exists
raw_data.isnull().sum()
# Out:
# 1. open                 0
# 2. high                 0
# 3. low                  0
# 4. close                0
# 5. adjusted close       0
# 6. volume               0
# 7. dividend amount      0
# 8. split coefficient    0
# Ticker                  0
# Date                    0
# dtype: int64

# %%
#get stock data information
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 538 entries, 2019-01-02 to 2021-02-19
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   1. open               538 non-null    float64
#  1   2. high               538 non-null    float64
#  2   3. low                538 non-null    float64
#  3   4. close              538 non-null    float64
#  4   5. adjusted close     538 non-null    float64
#  5   6. volume             538 non-null    float64
#  6   7. dividend amount    538 non-null    float64
#  7   8. split coefficient  538 non-null    float64
#  8   Ticker                538 non-null    object
#  9   Date                  538 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(8), object(1)
# memory usage: 46.2+ KB
